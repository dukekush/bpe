# %%
from volleyball_analysers import VideoGenerator
import os

# %%
gen = VideoGenerator('attack_pose_data/excel_files/REFERENCE_POSE_table.xlsx')
gen.show_frame(59, 1000, 500)
gen.create_stick_video('attack_pose_data/video_files/REFERENCE_POSE.mp4', 24)
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1920, 1080) to (1920, 1088) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).

# %%
for file in os.listdir('attack_pose_data/excel_files'):
    gen = VideoGenerator('attack_pose_data/excel_files/' + file)
    if file == 'REFERENCE_POSE_table.xlsx':
        gen.create_stick_video('attack_pose_data/video_files/' + file.replace('.xlsx', '.mp4'), 24)
    else:
        gen.create_stick_video('attack_pose_data/video_files/' + file.replace('.xlsx', '_reversed.mp4'), 60)
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1920, 1080) to (1920, 1088) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1920, 1080) to (1920, 1088) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1920, 1080) to (1920, 1088) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ...
